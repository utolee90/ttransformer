# %% [markdown]
# #

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn

# %%
# train, test 결과 불러오기
# iTransformer, test 결과 불러오기

result_path = './results/'
# cases four
# iTransformer (6:2:2)
# iTransformer with 0.5 trend + .5 linear
# iTransformer with .1 seasonal

original_iT = 'long_term_forecast_DiTransformer_Exchange_96_96_comp_reduced_dmodel_t0.6_Mod-DiTransformer_decomp_data-exchange_rate.csv_(96to96)_0(1726807836)'
half_linear = 'long_term_forecast_DiTransformer_Exchange_96_96_lin_half_test_Mod-DiTransformer_decomp_data-exchange_rate.csv_(96to96)_0(1726808764)'
one_tenth_seasonal = 'long_term_forecast_DiTransformer_Exchange_96_96_lin_half_little_seasonal_Mod-DiTransformer_decomp_data-exchange_rate.csv_(96to96)_0(1726811576)'

# %%
obj_list = ['pred.npy', 'true.npy']
obj_train_list = ['pred_train.npy', 'true_train.npy']

# original부터 불러기기
np_train_pred = np.load(result_path + original_iT + '/' + obj_train_list[0]) 
np_train_true = np.load(result_path + original_iT + '/' + obj_train_list[1]) 
np_test_pred = np.load(result_path + original_iT + '/' + obj_list[0]) 
np_test_true = np.load(result_path + original_iT + '/' + obj_list[1])

# %%
from utils.metrics import *

# %%
np_train_pred.shape, np_train_true.shape
# Out:
# ((30527, 96, 8), (30527, 96, 8))

# %%
# %matplotlib inline

# %%
idx = 0
val = 0
xr = range(96)
plt.plot(xr, np_train_pred[idx, :, val],'g', label=f'pred_{idx}_{val}' )
plt.plot(xr, np_train_true[idx, :, val],'c', label=f'true_{idx}_{val}' )
plt.legend()
plt.show()

print("MSE")
print(MSE(np_train_pred[idx, :, val], np_train_true[idx, :, val]))
print("MAE")
print(MAE(np_train_pred[idx, :, val], np_train_true[idx, :, val]))
print("SMAE")
print(SMAE(np_train_pred[idx, :, val], np_train_true[idx, :, val]))
print("REC_CORR")
print(np.corrcoef(np_train_pred[idx, :, val], np_train_true[idx, :, val])[0,1])
print("STD_RATIO")
print(np.std(np_train_true[idx, :, val])/np.std(np_train_pred[idx, :, val]))
print("SLOPE_RATIO")
print(get_slope(np.array(xr), np_train_true[idx, :, val])/get_slope(np.array(xr), np_train_pred[idx, :, val]))
# Out:
# MSE
# 0.044523995
# MAE
# 0.17266701
# SMAE
# 0.14435007
# REC_CORR
# -0.04070808584770808
# STD_RATIO
# 1.4302984
# SLOPE_RATIO
# -8.483042716704382

# %%
# MSE_DITRIB
xr = list(range(0, len(np_train_pred), 100))
yr_mean = []
yr_last = []
for idx in range(0, len(np_train_pred), 100):
    yr_mean.append(MSE(np_train_pred[idx, :, :], np_train_true[idx, :, :]))
    yr_last.append(MSE(np_train_pred[idx, :, -1], np_train_true[idx, :, -1]))

plt.figure(figsize=(25,5))
plt.plot(xr, yr_mean, label='mean-val')
plt.plot(xr, yr_last, label='last-val')
plt.plot(xr, np.mean(yr_mean) * np.ones(len(yr_mean)), label='total-mean')
plt.legend()
plt.show()

# %%
# MAE_DITRIB
yr_mean_mae = []
yr_last_mae = []
for idx in range(0, len(np_train_pred), 100):
    yr_mean_mae.append(MAE(np_train_pred[idx, :, :], np_train_true[idx, :, :]))
    yr_last_mae.append(MAE(np_train_pred[idx, :, -1], np_train_true[idx, :, -1]))

plt.figure(figsize=(25,5))
plt.plot(xr, yr_mean_mae, label='mean-val')
plt.plot(xr, yr_last_mae, label='last-val')
plt.plot(xr, np.mean(yr_mean_mae) * np.ones(len(yr_mean)), label='total-mean')
plt.legend()
plt.show()

# %%
# SMAE_DITRIB
yr_mean_smae = []
yr_last_smae = []
for idx in range(0, len(np_train_pred), 100):
    yr_mean_smae.append(SMAE(np_train_pred[idx, :, :], np_train_true[idx, :, :]))
    yr_last_smae.append(SMAE(np_train_pred[idx, :, -1], np_train_true[idx, :, -1]))

plt.figure(figsize=(25,5))
plt.plot(xr, yr_mean_smae, label='mean-val')
plt.plot(xr, yr_last_smae, label='last-val')
plt.plot(xr, np.mean(yr_mean_smae) * np.ones(len(yr_mean)), label='total-mean')
plt.legend()
plt.show()

# %%
yr_mean_corr = []
yr_last_corr = []

# %%
# CORR_DITRIB
xr = list(range(0, len(np_train_pred), 100))
yr_mean_corr = []
yr_last_corr = []
for idx in range(0, len(np_train_pred), 100):
    yr_mean_corr.append(REC_CORR(np_train_pred[idx, :, :], np_train_true[idx, :, :], 'median'))
    yr_last_corr.append(np.corrcoef(np_train_pred[idx, :, -1], np_train_true[idx, :, -1])[0,1])

plt.figure(figsize=(25,5))
plt.plot(xr, yr_mean_corr, label='median-val')
plt.plot(xr, yr_last_corr, label='last-val')
plt.plot(xr, np.median(yr_mean_corr) * np.ones(len(yr_mean)), label='total-mean')
plt.legend()
plt.show()
# Out:
# /home/yohan/anaconda3/envs/TSL/lib/python3.8/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/yohan/anaconda3/envs/TSL/lib/python3.8/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# histogram 분석
plt.hist(yr_mean_corr, color = 'yellow', alpha = 0.8, bins = 50, label='median')
plt.hist(yr_last_corr, color = 'black', alpha = 0.2, bins = 50, label='last')
plt.legend()
plt.show()

# %%
# SLOPE_DITRIB
xr = list(range(0, len(np_train_pred), 100))
yr_mean_slope = []
yr_last_slope = []
for idx in range(0, len(np_train_pred), 100):
    yr_mean_slope.append(SLOPE_RATIO(np_train_pred[idx, :, :], np_train_true[idx, :, :]) )
    yr_last_slope.append(96 * (
        get_slope(np.array(range(96)), np_train_true[idx, :, -1]) - get_slope(np.array(range(96)), np_train_pred[idx, :, -1])))

plt.figure(figsize=(25,5))
plt.plot(xr, yr_mean_slope, label='mean-val')
plt.plot(xr, yr_last_slope, label='last-val')
plt.plot(xr, np.mean(yr_mean_slope) * np.ones(len(yr_mean)), label='total-mean')
plt.legend()
plt.show()

# %%
idx = 3
val = 5
xr = range(96)
plt.plot(xr, np_train_pred[idx, :, val],'g', label=f'pred_{idx}_{val}' )
plt.plot(xr, np_train_true[idx, :, val],'c', label=f'true_{idx}_{val}' )
plt.legend()
plt.show()

print("MSE")
print(MSE(np_train_pred[idx, :, val], np_train_true[idx, :, val]))
print("MAE")
print(MAE(np_train_pred[idx, :, val], np_train_true[idx, :, val]))
print("SMAE")
print(SMAE(np_train_pred[idx, :, val], np_train_true[idx, :, val]))
print("REC_CORR")
print(np.corrcoef(np_train_pred[idx, :, val], np_train_true[idx, :, val])[0,1])
print("STD_RATIO")
print(np.std(np_train_true[idx, :, val])/np.std(np_train_pred[idx, :, val]))
print("SLOPE_RATIO")
print(get_slope(np.array(xr), np_train_true[idx, :, val])/get_slope(np.array(xr), np_train_pred[idx, :, val]))
# Out:
# MSE
# 0.2700186
# MAE
# 0.44460765
# SMAE
# -0.37473413
# REC_CORR
# 0.1891340260129267
# STD_RATIO
# 2.2018116
# SLOPE_RATIO
# 8.334025243746401

# %%
idx = 123
val = 7
xr0 = range(96)
plt.plot(xr, np_train_pred[idx, :, val],'g', label=f'pred_{idx}_{val}' )
plt.plot(xr, np_train_true[idx, :, val],'c', label=f'true_{idx}_{val}' )
plt.legend()
plt.show()

print("MSE")
print(MSE(np_train_pred[idx, :, val], np_train_true[idx, :, val]))
print("MAE")
print(MAE(np_train_pred[idx, :, val], np_train_true[idx, :, val]))
print("SMAE")
print(SMAE(np_train_pred[idx, :, val], np_train_true[idx, :, val]))
print("REC_CORR")
print(np.corrcoef(np_train_pred[idx, :, val], np_train_true[idx, :, val])[0,1])
print("STD_RATIO")
print(np.std(np_train_true[idx, :, val])/np.std(np_train_pred[idx, :, val]))
print("SLOPE_RATIO")
print(96*(get_slope(np.array(xr), np_train_true[idx, :, val])-get_slope(np.array(xr), np_train_pred[idx, :, val])))
# Out:
# MSE
# 0.03440175
# MAE
# 0.16142152
# SMAE
# 0.15845208
# REC_CORR
# -0.05930459721785175
# STD_RATIO
# 0.9829657
# SLOPE_RATIO
# 0.10197781867070231

# %%
idx = 11100
print(np.mean([np.corrcoef(np_train_pred[idx, :, val], np_train_true[idx, :, val])[0,1] for val in range(8)]))
print(REC_CORR(np_train_pred, np_train_true))
# Out:
# 0.2368858474494201
# 0.017112140800313747

# %%
# 이번엔 linear 데이터 불러기기
np_train_pred2 = np.load(result_path + half_linear + '/' + obj_train_list[0]) 
np_train_true2 = np.load(result_path + half_linear + '/' + obj_train_list[1]) 
np_test_pred2 = np.load(result_path + half_linear + '/' + obj_list[0]) 
np_test_true2 = np.load(result_path + half_linear + '/' + obj_list[1])

# %%
idx = 123
val = 7
xr = range(96)
plt.plot(xr, np_train_pred2[idx, :, val],'g', label=f'pred_{idx}_{val}' )
plt.plot(xr, np_train_true2[idx, :, val],'c', label=f'true_{idx}_{val}' )
plt.legend()
plt.show()

print("MSE")
print(MSE(np_train_pred2[idx, :, val], np_train_true2[idx, :, val]))
print("MAE")
print(MAE(np_train_pred2[idx, :, val], np_train_true2[idx, :, val]))
print("SMAE")
print(SMAE(np_train_pred2[idx, :, val], np_train_true2[idx, :, val]))
print("REC_CORR")
print(np.corrcoef(np_train_pred2[idx, :, val], np_train_true2[idx, :, val])[0,1])
print("STD_RATIO")
print(np.std(np_train_true2[idx, :, val])/np.std(np_train_pred2[idx, :, val]))
print("SLOPE_RATIO")
print(96*(get_slope(np.array(xr), np_train_true2[idx, :, val])-get_slope(np.array(xr), np_train_pred2[idx, :, val])))
# Out:
# MSE
# 0.008626883
# MAE
# 0.07727381
# SMAE
# -0.021651464
# REC_CORR
# 0.24812109860440412
# STD_RATIO
# 0.8165663
# SLOPE_RATIO
# -0.10424189411035004

# %%
# MSE_DITRIB
xr2 = list(range(0, len(np_train_pred2), 100))
yr_mean2 = []
yr_last2 = []
for idx in range(0, len(np_train_pred2), 100):
    yr_mean2.append(MSE(np_train_pred2[idx, :, :], np_train_true2[idx, :, :]))
    yr_last2.append(MSE(np_train_pred2[idx, :, -1], np_train_true2[idx, :, -1]))

plt.figure(figsize=(25,5))
plt.plot(xr2, yr_mean2, label='mean-val')
plt.plot(xr2, yr_last2, label='last-val')
plt.plot(xr2, np.mean(yr_mean2) * np.ones(len(yr_mean2)), label='total-mean')
plt.legend()
plt.show()

# %%
# MAE_DITRIB
yr_mean_mae2 = []
yr_last_mae2 = []
for idx in range(0, len(np_train_pred2), 100):
    yr_mean_mae2.append(MAE(np_train_pred2[idx, :, :], np_train_true2[idx, :, :]))
    yr_last_mae2.append(MAE(np_train_pred2[idx, :, -1], np_train_true2[idx, :, -1]))

plt.figure(figsize=(25,5))
plt.plot(xr2, yr_mean_mae2, label='mean-val')
plt.plot(xr2, yr_last_mae2, label='last-val')
plt.plot(xr2, np.mean(yr_mean_mae2) * np.ones(len(yr_mean2)), label='total-mean')
plt.legend()
plt.show()

# %%
# SMAE_DITRIB
yr_mean_smae2 = []
yr_last_smae2 = []
for idx in range(0, len(np_train_pred2), 100):
    yr_mean_smae2.append(SMAE(np_train_pred[idx, :, :], np_train_true[idx, :, :]))
    yr_last_smae2.append(SMAE(np_train_pred[idx, :, -1], np_train_true[idx, :, -1]))

plt.figure(figsize=(25,5))
plt.plot(xr2, yr_mean_smae2, label='mean-val')
plt.plot(xr2, yr_last_smae2, label='last-val')
plt.plot(xr2, np.mean(yr_mean_smae2) * np.ones(len(yr_mean2)), label='total-mean')
plt.legend()
plt.show()

# %%
SMAE(np_train_pred, np_train_true), SMAE(np_train_pred2, np_train_true2)
# Out:
# (0.008685997, 0.009317854)

# %%
# CORR_DITRIB
xr = list(range(0, len(np_train_pred2), 100))
yr_mean_corr2 = []
yr_last_corr2 = []
for idx in range(0, len(np_train_pred2), 100):
    yr_mean_corr2.append(REC_CORR(np_train_pred2[idx, :, :], np_train_true2[idx, :, :], 'median'))
    yr_last_corr2.append(np.corrcoef(np_train_pred2[idx, :, -1], np_train_true2[idx, :, -1])[0,1])

plt.figure(figsize=(25,5))
plt.plot(xr, yr_mean_corr2, label='median-val')
plt.plot(xr, yr_last_corr2, label='last-val')
plt.plot(xr, np.median(yr_mean_corr2) * np.ones(len(yr_mean2)), label='total-mean')
plt.legend()
plt.show()

# %%
np.median(yr_mean_corr2), np.median(yr_mean_corr), np.median(yr_last_corr2), np.median(yr_last_corr)
# Out:
# (-0.012483488815186135,
#  0.023058373123509144,
#  -0.034020276141791,
#  -0.03846005303072436)

# %%
np.mean(yr_mean_corr2), np.mean(yr_mean_corr), np.mean(yr_last_corr2), np.mean(yr_last_corr)
# Out:
# (0.004322927704577132,
#  0.030749831319310673,
#  -0.01913934698994566,
#  -0.05535309311069328)

# %%
np.max(yr_mean_corr2), np.max(yr_mean_corr), np.min(yr_mean_corr2), np.min(yr_mean_corr)
# Out:
# (0.5610551931529622,
#  0.6281684174504631,
#  -0.5246357459541647,
#  -0.5322835475616705)

# %%
np.max(yr_last_corr2), np.max(yr_last_corr), np.min(yr_last_corr2), np.min(yr_last_corr)
# Out:
# (0.8096806506813404,
#  0.729674199690983,
#  -0.6656636003988841,
#  -0.7137240540557027)

# %%
# histogram 분석
plt.hist(yr_mean_corr2, color = 'yellow', alpha = 0.8, bins = 50, label='median')
plt.hist(yr_last_corr2, color = 'black', alpha = 0.2, bins = 50, label='last')
plt.legend()
plt.show()

# %%
# SLOPE_DITRIB
xr = list(range(0, len(np_train_pred2), 100))
yr_mean_slope2 = []
yr_last_slope2 = []
for idx in range(0, len(np_train_pred2), 100):
    yr_mean_slope2.append(SLOPE_RATIO(np_train_pred2[idx, :, :], np_train_true2[idx, :, :]) )
    yr_last_slope2.append(96 * (
        get_slope(np.array(range(96)), np_train_true2[idx, :, -1]) - get_slope(np.array(range(96)), np_train_pred2[idx, :, -1])))

plt.figure(figsize=(25,5))
plt.plot(xr, yr_mean_slope2, label='mean-val')
plt.plot(xr, yr_last_slope2, label='last-val')
plt.plot(xr, np.mean(yr_mean_slope2) * np.ones(len(yr_mean2)), label='total-mean')
plt.legend()
plt.show()

# %%
# STD_DITRIB
xr = list(range(0, len(np_train_pred2), 100))
yr_mean_std2 = []
yr_last_std2 = []
for idx in range(0, len(np_train_pred2), 100):
    yr_mean_std2.append(STD_RATIO(np_train_pred2[idx, :, :], np_train_true2[idx, :, :], 'median') )
    yr_last_std2.append(np.std(np_train_true2[idx, :, -1])/np.std(np_train_pred2[idx, :, -1]))

plt.figure(figsize=(25,5))
plt.plot(xr, yr_mean_std2, label='mean-val')
plt.plot(xr, yr_last_std2, label='last-val')
plt.plot(xr, np.mean(yr_mean_std2) * np.ones(len(yr_mean2)), label='total-mean')
plt.legend()
plt.show()

# %%
# 결과 데이터로도 분석

np_test_pred
np_test_true
np_test_pred2
np_test_true2.shape
# Out:
# (1422, 96, 8)

# %%
MSE(np_test_pred, np_test_true), MSE(np_test_pred[:,:,-1], np_test_true[:,:,-1]), MSE(np_test_pred2, np_test_true2), MSE(np_test_pred2[:,:,-1], np_test_true2[:,:,-1])
# Out:
# (0.11036256, 0.10463235, 0.10488787, 0.1023529)

# %%
MAE(np_test_pred, np_test_true), MAE(np_test_pred[:,:,-1], np_test_true[:,:,-1]), MAE(np_test_pred2, np_test_true2), MAE(np_test_pred2[:,:,-1], np_test_true2[:,:,-1])
# Out:
# (0.23223016, 0.24067545, 0.22770016, 0.24016584)

# %%
SMAE(np_test_pred, np_test_true), SMAE(np_test_pred[:,:,-1], np_test_true[:,:,-1]), SMAE(np_test_pred2, np_test_true2), SMAE(np_test_pred2[:,:,-1], np_test_true2[:,:,-1])
# Out:
# (-0.08025815, -0.053103354, -0.049962826, -0.02490006)

# %%
REC_CORR(np_test_pred, np_test_true), REC_CORR(np_test_pred[:,:,-1:], np_test_true[:,:,-1:]), REC_CORR(np_test_pred2, np_test_true2), REC_CORR(np_test_pred2[:,:,-1:], np_test_true2[:,:,-1:])
# Out:
# (0.005696640664425866,
#  0.04441150569393033,
#  0.0031352718922871125,
#  0.013064051595052511)

# %%
SLOPE_RATIO(np_test_pred, np_test_true), SLOPE_RATIO(np_test_pred[:,:,-1:], np_test_true[:,:,-1:]), SLOPE_RATIO(np_test_pred2, np_test_true2), SLOPE_RATIO(np_test_pred2[:,:,-1:], np_test_true2[:,:,-1:])
# Out:
# (-0.1529439216020195,
#  -0.09452832909515954,
#  -0.14614997241936373,
#  -0.09022568071015508)

# %%
STD_RATIO(np_test_pred, np_test_true), STD_RATIO(np_test_pred[:,:,-1:], np_test_true[:,:,-1:]), STD_RATIO(np_test_pred2, np_test_true2), STD_RATIO(np_test_pred2[:,:,-1:], np_test_true2[:,:,-1:])
# Out:
# (6.082688, 6.064874, 5.5971417, 5.6333923)

# %%
# 과연 linear term의 차이는 큰 것인가?

np_test_pred_trend = np.load(result_path + original_iT + '/' + 'pred_trend.npy') 
np_test_pred_trend2 = np.load(result_path + half_linear + '/' + 'pred_trend.npy') 
np_test_true_trend = np.load(result_path + original_iT + '/' + 'true_trend.npy')
np_test_true_trend2 = np.load(result_path + half_linear + '/' + 'true_trend.npy')
np_test_pred_seasonal = np.load(result_path + original_iT + '/' + 'pred_seasonal.npy') 
np_test_pred_seasonal2 = np.load(result_path + half_linear + '/' + 'pred_seasonal.npy') 
np_test_true_seasonal = np.load(result_path + original_iT + '/' + 'true_seasonal.npy')
np_test_true_seasonal2 = np.load(result_path + half_linear + '/' + 'true_seasonal.npy')

# %%
only_linear = 'long_term_forecast_DiTransformer_Exchange_96_96_only_linear_Mod-DiTransformer_decomp_data-exchange_rate.csv_(96to96)_0(1726813290)'
np_test_pred3 = np.load(result_path + only_linear + '/' + 'pred.npy') 
np_test_true3 = np.load(result_path + only_linear + '/' + 'true.npy') 
np_test_pred_trend3 = np.load(result_path + only_linear + '/' + 'pred_trend.npy') 
np_test_pred_seasonal3 = np.load(result_path + only_linear + '/' + 'pred_seasonal.npy')

# %%
idx = 234
val = 0
xr = range(96)
plt.plot(xr, np_test_pred_trend[idx, :, val],'g', label=f'pred_t_o_{idx}_{val}' )
plt.plot(xr, np_test_pred_trend2[idx, :, val],'c', label=f'pred_t_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred_trend3[idx, :, val],'b', label=f'pred_t_lin_{idx}_{val}' )
plt.plot(xr, np_test_true_trend[idx, :, val],'k', label=f'true_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
idx = 234
val = 0
xr = range(96)
plt.plot(xr, np_test_pred_seasonal[idx, :, val],'g', label=f'pred_s_o_{idx}_{val}' )
plt.plot(xr, np_test_pred_seasonal2[idx, :, val],'c', label=f'pred_s_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred_seasonal3[idx, :, val],'b', label=f'pred_s_lin_{idx}_{val}' )
plt.plot(xr, np_test_true_seasonal[idx, :, val],'k', label=f'true_s_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
idx = 234
val = 0
xr = range(96)
plt.plot(xr, np_test_pred[idx, :, val],'g', label=f'pred_o_{idx}_{val}' )
plt.plot(xr, np_test_pred2[idx, :, val],'c', label=f'pred_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred3[idx, :, val],'b', label=f'pred_lin_{idx}_{val}' )
plt.plot(xr, np_test_true[idx, :, val],'k', label=f'true_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
idx = 1024
val = 7
xr = range(96)
plt.plot(xr, np_test_pred_trend[idx, :, val],'g', label=f'pred_t_o_{idx}_{val}' )
plt.plot(xr, np_test_pred_trend2[idx, :, val],'c', label=f'pred_t_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred_trend3[idx, :, val],'b', label=f'pred_t_lin_{idx}_{val}' )
plt.plot(xr, np_test_true_trend[idx, :, val],'k', label=f'true_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
idx = 1024
val = 7
xr = range(96)
plt.plot(xr, np_test_pred_seasonal[idx, :, val],'g', label=f'pred_s_o_{idx}_{val}' )
plt.plot(xr, np_test_pred_seasonal2[idx, :, val],'c', label=f'pred_s_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred_seasonal3[idx, :, val],'b', label=f'pred_s_lin_{idx}_{val}' )
plt.plot(xr, np_test_true_seasonal[idx, :, val],'k', label=f'true_s_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
idx = 1024
val = 7
xr = range(96)
plt.plot(xr, np_test_pred[idx, :, val],'g', label=f'pred_o_{idx}_{val}' )
plt.plot(xr, np_test_pred2[idx, :, val],'c', label=f'pred_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred3[idx, :, val],'b', label=f'pred_lin_{idx}_{val}' )
plt.plot(xr, np_test_true[idx, :, val],'k', label=f'true_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
idx = 0
val = 0
xr = range(96)
plt.plot(xr, np_test_pred[idx, :, val],'g', label=f'pred_o_{idx}_{val}' )
plt.plot(xr, np_test_pred2[idx, :, val],'c', label=f'pred_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred3[idx, :, val],'b', label=f'pred_lin_{idx}_{val}' )
plt.plot(xr, np_test_true[idx, :, val],'k', label=f'true_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
idx = 0
val = 0
xr = range(96)
plt.plot(xr, np_test_pred_trend[idx, :, val],'g', label=f'pred_t_o_{idx}_{val}' )
plt.plot(xr, np_test_pred_trend2[idx, :, val],'c', label=f'pred_t_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred_trend3[idx, :, val],'b', label=f'pred_t_lin_{idx}_{val}' )
plt.plot(xr, np_test_true_trend[idx, :, val],'k', label=f'true_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
idx = 0
val = 0
xr = range(96)
plt.plot(xr, np_test_pred_seasonal[idx, :, val],'g', label=f'pred_s_o_{idx}_{val}' )
plt.plot(xr, np_test_pred_seasonal2[idx, :, val],'c', label=f'pred_s_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred_seasonal3[idx, :, val],'b', label=f'pred_s_lin_{idx}_{val}' )
plt.plot(xr, np_test_true_seasonal[idx, :, val],'k', label=f'true_s_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
idx = 742
val = 4
xr = range(96)
plt.plot(xr, np_test_pred[idx, :, val],'g', label=f'pred_o_{idx}_{val}' )
plt.plot(xr, np_test_pred2[idx, :, val],'c', label=f'pred_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred3[idx, :, val],'b', label=f'pred_lin_{idx}_{val}' )
plt.plot(xr, np_test_true[idx, :, val],'k', label=f'true_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
idx = 742
val = 4
xr = range(96)
plt.plot(xr, np_test_pred_trend[idx, :, val],'g', label=f'pred_t_o_{idx}_{val}' )
plt.plot(xr, np_test_pred_trend2[idx, :, val],'c', label=f'pred_t_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred_trend3[idx, :, val],'b', label=f'pred_t_lin_{idx}_{val}' )
plt.plot(xr, np_test_true_trend[idx, :, val],'k', label=f'true_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
idx = 742
val = 4
xr = range(96)
plt.plot(xr, np_test_pred_seasonal[idx, :, val],'g', label=f'pred_s_o_{idx}_{val}' )
plt.plot(xr, np_test_pred_seasonal2[idx, :, val],'c', label=f'pred_s_hf_{idx}_{val}' )
plt.plot(xr, np_test_pred_seasonal3[idx, :, val],'b', label=f'pred_s_lin_{idx}_{val}' )
plt.plot(xr, np_test_true_seasonal[idx, :, val],'k', label=f'true_s_o_{idx}_{val}' )
plt.legend()
plt.show()

# %%
# 오차비교 결과
# 오차1 (iTransformer 예측값, iTransformer+linear 예측값) / 오차2(iTransformer 예측값, linear 치환 예측값) / 오차3 (iTransformer 예측값, 참값)

# %%
# 오차비교 - 참값 대비 모델 예측값의 오차가 확 작은지 확인?
MSE(np_test_pred, np_test_pred2), MSE(np_test_pred, np_test_pred3), MSE(np_test_pred, np_test_true)
# Out:
# (0.004675213, 0.024097089, 0.11036256)

# %%
# 오차비교 - 참값 대비 모델 예측값의 오차가 확 작은지 확인?
MSE(np_test_pred[:,:,-1], np_test_pred2[:,:,-1]), MSE(np_test_pred[:,:,-1], np_test_pred3[:,:,-1]), MSE(np_test_pred[:,:,-1], np_test_true[:,:,-1])
# Out:
# (0.0036772322, 0.021020016, 0.10463235)

# %%
# 오차비교 - MAE
MAE(np_test_pred, np_test_pred2), MAE(np_test_pred, np_test_pred3), MAE(np_test_pred, np_test_true)
# Out:
# (0.04928378, 0.0964053, 0.23223016)

# %%
# 오차비교 - ME (평균 오류)
SMAE(np_test_pred, np_test_pred2), SMAE(np_test_pred, np_test_pred3), SMAE(np_test_pred, np_test_true)
# Out:
# (-0.03029531, -0.019065192, -0.08025815)

# %%
# 오차비교 - 상관수수
REC_CORR(np_test_pred, np_test_pred2), REC_CORR(np_test_pred, np_test_pred3), REC_CORR(np_test_pred, np_test_true)
# Out:
# (0.7114457035492804, 0.2660551088825429, 0.005696640664425866)

# %%
# 오차비교 - 표준편차
STD_RATIO(np_test_pred, np_test_pred2), STD_RATIO(np_test_pred, np_test_pred3), STD_RATIO(np_test_pred, np_test_true)
# Out:
# (1.0867488, 2.758659, 6.082688)

# %%
# 오차비교 - 기울기 편차
SLOPE_RATIO(np_test_pred, np_test_pred2), SLOPE_RATIO(np_test_pred, np_test_pred3), SLOPE_RATIO(np_test_pred, np_test_true)
# Out:
# (-0.006793949182655764, -0.04078150481761599, -0.1529439216020195)
